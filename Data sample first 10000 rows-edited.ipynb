# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # User

# %%
user1 = pd.read_csv('user1.csv')
user1
# Out:
#                        user_id      name  review_count        yelping_since  \
# 0       qVc8ODYU5SZjKXVBgXdI7w    Walker           585  2007-01-25 16:47:26
# 1       j14WgRoU_-2ZE1aw1dXrJg    Daniel          4333  2009-01-25 04:35:42
# 2       2WnXYQFK0hXEoTxPtV2zvg     Steph           665  2008-07-25 10:41:00
# 3       SZDeASXq7o05mMNLshsdIA      Gwen           224  2005-11-29 04:38:33
# 4       hA5lMy-EnncsH4JoR-hFGQ     Karen            79  2007-01-05 19:40:59
# ...                        ...       ...           ...                  ...
# 199995  y-1YkRfAGhmYXvpu412H4A  Michaela           526  2006-05-29 03:14:41
# 199996  T3wdKRBfHPpydOob4rESPQ   DR.Paul            11  2011-09-22 12:25:42
# 199997  UiRx8jyS6H957ItwFsP2nQ       Jim            68  2012-05-03 17:30:52
# 199998  8qlpLJ17opq15w461eCfvA  Jonathan           217  2010-05-19 23:31:30
# 199999  tSdz6ZkR0psn41cCaaTlYw      Alyx          1263  2012-09-02 06:27:25
#
#         useful  funny   cool  \
# ...

# %%
# First 10000 rows in User
# head = pd.read_csv('user1.csv', nrows=10000)
# head = user1.head(10000)
user_sample_10000 = pd.read_csv('user1.csv', nrows=10000)
user_sample_10000
# Out:
#                      user_id    name  review_count        yelping_since  \
# 0     qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26
# 1     j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42
# 2     2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00
# 3     SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33
# 4     hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59
# ...                      ...     ...           ...                  ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w   Allen             5  2010-07-17 20:19:51
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ  Shanel            43  2010-10-09 21:28:32
# 9997  nbF6fWySgbbD15TGSOKN6Q  Britta            43  2010-09-19 00:13:03
# 9998  rVuP6BdGt_8QF7PA0kRyvQ     Nel           392  2011-07-15 22:54:35
# 9999  fPvAAXp-B-fTS3_HOxvqlg     Jon            76  2008-07-06 04:11:54
#
#       useful  funny   cool                                              elite  \
# ...

# %%
user_sample_10000 = user_sample_10000.drop(columns = ['name','friends'])
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  useful  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26    7217
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42   43091
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00    2086
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33     512
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59      29
# ...                      ...           ...                  ...     ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51       4
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32      60
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03     102
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35     278
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54      97
#
#       funny   cool                                              elite  fans  \
# ...

# %%
# sum compliment --> creat a new column called compliment
# sum_column = df["col1"] + df["col2"]

# %%
# df['Jan_Feb'] = df.loc[: , ['Jan', 'Feb']].sum(axis=1)
user_sample_10000['total_compliments'] = user_sample_10000.loc[:, ['compliment_hot','compliment_more','compliment_profile','compliment_cute','compliment_list','compliment_note','compliment_plain','compliment_cool','compliment_funny','compliment_writer','compliment_photos']].sum(axis=1)

# %%
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  useful  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26    7217
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42   43091
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00    2086
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33     512
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59      29
# ...                      ...           ...                  ...     ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51       4
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32      60
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03     102
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35     278
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54      97
#
#       funny   cool                                              elite  fans  \
# ...

# %%
# drop compliment related columns
user_sample_10000 = user_sample_10000.drop(columns = ['compliment_hot','compliment_more','compliment_profile','compliment_cute','compliment_list','compliment_note','compliment_plain','compliment_cool','compliment_funny','compliment_writer','compliment_photos'])
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  useful  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26    7217
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42   43091
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00    2086
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33     512
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59      29
# ...                      ...           ...                  ...     ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51       4
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32      60
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03     102
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35     278
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54      97
#
#       funny   cool                                              elite  fans  \
# ...

# %%
# Sum funny, cool and useful columns together? -> creat a new column called positive review
#  df['Jan_Feb'] = df.loc[: , ['Jan', 'Feb']].sum(axis=1)

# %%
user_sample_10000['positive_reactions'] = user_sample_10000.loc[:, ['useful', 'funny', 'cool']].sum(axis = 1)
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  useful  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26    7217
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42   43091
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00    2086
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33     512
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59      29
# ...                      ...           ...                  ...     ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51       4
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32      60
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03     102
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35     278
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54      97
#
#       funny   cool                                              elite  fans  \
# ...

# %%
# drop columns : useful, funny, cool

# %%
user_sample_10000 = user_sample_10000.drop(columns = ['useful', 'funny', 'cool'])

# %%
user_sample_10000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             10000 non-null  object
#  1   review_count        10000 non-null  int64
#  2   yelping_since       10000 non-null  object
#  3   elite               4933 non-null   object
#  4   fans                10000 non-null  int64
#  5   average_stars       10000 non-null  float64
#  6   total_compliments   10000 non-null  int64
#  7   positive_reactions  10000 non-null  int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 625.1+ KB

# %%
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59
# ...                      ...           ...                  ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54
#
#                                                   elite  fans  average_stars  \
# 0                                                  2007   267           3.91
# ...

# %% [markdown]
# # Review

# %%
review_sample_10000 = pd.read_csv('review1.csv', nrows=10000)
review_sample_10000
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1     BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2     saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  useful  funny  cool  \
# ...

# %%
review_sample_10000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    10000 non-null  object
#  1   user_id      10000 non-null  object
#  2   business_id  10000 non-null  object
#  3   stars        10000 non-null  int64
#  4   useful       10000 non-null  int64
#  5   funny        10000 non-null  int64
#  6   cool         10000 non-null  int64
#  7   text         10000 non-null  object
#  8   date         10000 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 703.2+ KB

# %%
# remove time (hours, minutes and seconds) from date
# 2015 cutoff,只保留2015年之后的review
# Sum funny, cool and useful columns together? -> creat a new column called positive review
# drop text

# %%
review_sample_10000['date'] = pd.to_datetime(review_sample_10000.date, format='%Y-%m-%d %H:%M:%S')
review_sample_10000
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1     BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2     saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  useful  funny  cool  \
# ...

# %%
review_sample_10000['date'] = review_sample_10000['date'].dt.date

# %%
review_sample_10000["year"] = review_sample_10000["date"].map(lambda x: x.year)

# %%
review_sample_10000
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1     BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2     saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  useful  funny  cool  \
# ...

# %%
# drop text, date

# %%
review_sample_10000 = review_sample_10000.drop(columns = ['text','date'])

# %%
review_sample_10000
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1     BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2     saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  useful  funny  cool  year
# ...

# %%
# remove data before 2015

# %%
review_sample_10000 = review_sample_10000[review_sample_10000.year >= 2015]

# %%
review_sample_10000
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5     JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 6     6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  useful  funny  cool  year
# ...

# %%
# Sum funny, cool and useful columns together? -> creat a new column called positive review

# %%
review_sample_10000['positive_reviews'] = review_sample_10000.loc[:, ['useful', 'funny', 'cool']].sum(axis = 1)
review_sample_10000
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_35300/3052505577.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_sample_10000['positive_reviews'] = review_sample_10000.loc[:, ['useful', 'funny', 'cool']].sum(axis = 1)
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5     JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 6     6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# ...

# %%
# drop funny, cool and useful columns

# %%
review_sample_10000 = review_sample_10000.drop(columns = ['useful','funny','cool'])

# %%
review_sample_10000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6142 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   review_id         6142 non-null   object
#  1   user_id           6142 non-null   object
#  2   business_id       6142 non-null   object
#  3   stars             6142 non-null   int64
#  4   year              6142 non-null   int64
#  5   positive_reviews  6142 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 335.9+ KB

# %%
review_sample_10000
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5     JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 6     6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  year  positive_reviews
# ...

# %% [markdown]
# # Business

# %%
Business = pd.read_json('business.json',lines = True)
Business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
# Only keep Business_IDs with is_open =1
# drop latitidu and longitude
# drop business that has less than 3 stars (1 and 2 stars)

# %%
Business_open = Business.drop(Business[Business['is_open'] != 1 ].index)              # 条件 = 0 时报错 
Business_open
# Out:
#                    business_id                      name  \
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 5       CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 6       n_0UpQx1hsNbnPUSlodU8w           Famous Footwear
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                            address          city state  \
# 1                  87 Grasso Plaza Shopping Center        Affton    MO
# 3                                      935 Race St  Philadelphia    PA
# ...

# %%
#Business_open = Business_open.drop(columns = ['is_open','latitude','longitude'])
Business_open = Business_open.drop(columns = ['latitude','longitude'])

# %%
Business_open
# Out:
#                    business_id                      name  \
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 5       CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 6       n_0UpQx1hsNbnPUSlodU8w           Famous Footwear
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                            address          city state  \
# 1                  87 Grasso Plaza Shopping Center        Affton    MO
# 3                                      935 Race St  Philadelphia    PA
# ...

# %%
Business_open.describe()
# Out:
#                stars   review_count   is_open
# count  119698.000000  119698.000000  119698.0
# mean        3.618908      46.683963       1.0
# std         0.996255     130.820262       0.0
# min         1.000000       5.000000       1.0
# 25%         3.000000       8.000000       1.0
# 50%         4.000000      15.000000       1.0
# 75%         4.500000      37.000000       1.0
# max         5.000000    7568.000000       1.0

# %%
# Business_open = Business_open[Business_open.stars >= (Business_open['stars'].mean())]

# %%
Business_open = Business_open[Business_open.stars >= 3]
Business_open
# Out:
#                    business_id                      name  \
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 7       qkRM_2X51Yqxk3btlwAQIg            Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                 Marshalls
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address            city state postal_code  \
# 1       87 Grasso Plaza Shopping Center          Affton    MO       63123
# 3                           935 Race St    Philadelphia    PA       19107
# ...

# %%
Business_open.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94885 entries, 1 to 150345
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   94885 non-null  object
#  1   name          94885 non-null  object
#  2   address       94885 non-null  object
#  3   city          94885 non-null  object
#  4   state         94885 non-null  object
#  5   postal_code   94885 non-null  object
#  6   stars         94885 non-null  float64
#  7   review_count  94885 non-null  int64
#  8   is_open       94885 non-null  int64
#  9   attributes    86613 non-null  object
#  10  categories    94861 non-null  object
#  11  hours         83579 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 9.4+ MB

# %% [markdown]
# # Join 3 dataframe together

# %%
Business_open
# Out:
#                    business_id                      name  \
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 7       qkRM_2X51Yqxk3btlwAQIg            Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                 Marshalls
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address            city state postal_code  \
# 1       87 Grasso Plaza Shopping Center          Affton    MO       63123
# 3                           935 Race St    Philadelphia    PA       19107
# ...

# %%
review_sample_10000
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5     JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 6     6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  year  positive_reviews
# ...

# %%
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59
# ...                      ...           ...                  ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54
#
#                                                   elite  fans  average_stars  \
# 0                                                  2007   267           3.91
# ...

# %%
review_and_user_sample = review_sample_10000.merge(user_sample_10000, on = 'user_id', how = 'inner')
review_and_user_sample
# Out:
#                   review_id                 user_id             business_id  \
# 0    IJCYT9dRjuBvY-BJufFnNg  hWDybu_KvYLSdEFzGrniTw  roc-xyyzN5b_nImb0NdRLQ
# 1    g7MfpJGKQUGowCvIcrB91A  ci7Q6NvXQ8UZrBHusVX18g  V6Om7YZhlRQRU7WfuxHq8Q
# 2    WaeKsvHUJ8whjBlWjl0kaQ  yyxEa8y4HGij_m7g1wDKWg  Jc6MxMyCLp4DMfN4C1t1aQ
# 3    mRnYZes0nj4sr8DsE_gWMQ  FuTJWFYm4UKqewaosss1KA  fgTOJRkc703E4XRdcr5zRA
# 4    GY2rCySJI41AXWMXvrDTJg  nnImk681KaRqUVHlSfZjGQ  nFjk0xVI9fNiVN__5g-m8Q
# ..                      ...                     ...                     ...
# 171  ePPrEHTV699u-r_8FBsTjQ  xj3u-L1K5Dhq511eA2Z6Gw  ZiQiMlvgk19GrEEkN9kyRA
# 172  4NqvJJ63A3GWui8tXJ9EcQ  9SuP4YCScinm6M_Lak9_rA  H3JjbID9Zhukpqr9uupHAA
# 173  4rhOB2WvWfuJktHHW_7n1A  X0Bmllln5u8i37-Fo8leVg  N5ekxQd7wGHWJJK-p9qqXw
# 174  Vv0Re-rwUV7Qy7C919aQkg  P7kw2Cw8Z45kbrVjYAHr3w  TDKBPcViJQDMrdUm6a9XZA
# 175  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
#
# ...

# %%
# review_and_user_sample.join(Business_open, on = 'business_id')
# pd.concat(['review_and_user_sample', 'Business_open'], join = 'inner')
# Doesn't work

# %%
# review_and_user_sample.merge(Business_open, how = 'inner')                    => 0 record
# sample_10000 = review_and_user_sample.merge(Business_open, how = 'outer')     => 0 record
sample_10000 = pd.merge(review_and_user_sample, Business_open, how = 'inner', on = 'business_id', suffixes=('_R&U', '_B'))
sample_10000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 0 to 130
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           131 non-null    object
#  1   user_id             131 non-null    object
#  2   business_id         131 non-null    object
#  3   stars_R&U           131 non-null    int64
#  4   year                131 non-null    int64
#  5   positive_reviews    131 non-null    int64
#  6   review_count_R&U    131 non-null    int64
#  7   yelping_since       131 non-null    object
#  8   elite               80 non-null     object
#  9   fans                131 non-null    int64
#  10  average_stars       131 non-null    float64
#  11  total_compliments   131 non-null    int64
#  12  positive_reactions  131 non-null    int64
#  13  name                131 non-null    object
#  14  address             131 non-null    object
# ...

# %%
sample_10000 = sample_10000.rename(columns = {'average_stars' : 'user_average_stars'})

# %%
sample_10000 = sample_10000.rename(columns = {'positive_reviews' : 'review_positive_reactions', 'positive_reactions' : 'user_positive_reactions'})

# %%
sample_10000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 0 to 130
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   review_id                  131 non-null    object
#  1   user_id                    131 non-null    object
#  2   business_id                131 non-null    object
#  3   stars_R&U                  131 non-null    int64
#  4   year                       131 non-null    int64
#  5   review_positive_reactions  131 non-null    int64
#  6   review_count_R&U           131 non-null    int64
#  7   yelping_since              131 non-null    object
#  8   elite                      80 non-null     object
#  9   fans                       131 non-null    int64
#  10  user_average_stars         131 non-null    float64
#  11  total_compliments          131 non-null    int64
#  12  user_positive_reactions    131 non-null    int64
# ...

# %%
# groupby and count business on state
(sample_10000.groupby(by = 'state' ).count()).sort_values(by = 'review_id', ascending = False)
# Out:
#        review_id  user_id  business_id  stars_R&U  year  \
# state
# LA            32       32           32         32    32
# PA            28       28           28         28    28
# FL            18       18           18         18    18
# IN            12       12           12         12    12
# TN            11       11           11         11    11
# NV             8        8            8          8     8
# CA             6        6            6          6     6
# MO             5        5            5          5     5
# AZ             3        3            3          3     3
# ID             3        3            3          3     3
# AB             2        2            2          2     2
# NJ             2        2            2          2     2
# IL             1        1            1          1     1
#
#        review_positive_reactions  review_count_R&U  yelping_since  elite  \
# state
# LA                            32                32             32     21
# ...

# %%
sample_10000.groupby(by ='business_id').count().sort_values(by = 'review_id', ascending = False).head(10)
# Out:
#                         review_id  user_id  stars_R&U  year  \
# business_id
# I0I2mkCOPTYVSLpc8A8VVw          2        2          2     2
# jMZ56S8Y1t7cA1Ob-d-qeA          2        2          2     2
# N5ekxQd7wGHWJJK-p9qqXw          2        2          2     2
# kZ3L75t_7EqE9kRS6bpWSA          2        2          2     2
# grjFEAN9gXOKQFEta4yBJg          2        2          2     2
# ZY2feSm2sc5nTXYHnKpMGQ          2        2          2     2
# 8uF-bhJFgT4Tn6DTb27viA          2        2          2     2
# hS6KNGCQVTYUdLb2edt58g          1        1          1     1
# h4C7s_Go9UKo5twaLIWc8A          1        1          1     1
# hiEj-3X8gV4-kBNkySOSJw          1        1          1     1
#
#                         review_positive_reactions  review_count_R&U  \
# business_id
# I0I2mkCOPTYVSLpc8A8VVw                          2                 2
# jMZ56S8Y1t7cA1Ob-d-qeA                          2                 2
# N5ekxQd7wGHWJJK-p9qqXw                          2                 2
# ...

# %%
sample_10000['business_id'].duplicated().sum()
# Out:
# 7

# %%
sample_10000['user_id'].duplicated().sum()
# Out:
# 6

# %%
sample_10000['review_id'].duplicated().sum()
# Out:
# 0

# %%
sample_10000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 0 to 130
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   review_id                  131 non-null    object
#  1   user_id                    131 non-null    object
#  2   business_id                131 non-null    object
#  3   stars_R&U                  131 non-null    int64
#  4   year                       131 non-null    int64
#  5   review_positive_reactions  131 non-null    int64
#  6   review_count_R&U           131 non-null    int64
#  7   yelping_since              131 non-null    object
#  8   elite                      80 non-null     object
#  9   fans                       131 non-null    int64
#  10  user_average_stars         131 non-null    float64
#  11  total_compliments          131 non-null    int64
#  12  user_positive_reactions    131 non-null    int64
# ...

# %% [markdown]
# # categorize user

# %%
user_sample_10000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             10000 non-null  object
#  1   review_count        10000 non-null  int64
#  2   yelping_since       10000 non-null  object
#  3   elite               4933 non-null   object
#  4   fans                10000 non-null  int64
#  5   average_stars       10000 non-null  float64
#  6   total_compliments   10000 non-null  int64
#  7   positive_reactions  10000 non-null  int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 625.1+ KB

# %%
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59
# ...                      ...           ...                  ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54
#
#                                                   elite  fans  average_stars  \
# 0                                                  2007   267           3.91
# ...

# %%
user_sample_10000['fans'].quantile([.25, .5, .75, 1])
# Out:
# 0.25        2.0
# 0.50        7.0
# 0.75       25.0
# 1.00    12497.0
# Name: fans, dtype: float64

# %%
user_sample_10000[['fans']].boxplot()
# Out:
# <AxesSubplot:>

# %%
user_sample_10000[['fans']].plot()
# Out:
# <AxesSubplot:>

# %%
user_sample_10000['fans'].max()
# Out:
# 12497

# %%
user_sample_10000['fans'].mode()
# Out:
# 0    0
# dtype: int64

# %%
x = 'total_compliments'
y = 'total_compliments_tire'
for i in user_sample_10000.index:
    if user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.25):
        user_sample_10000.loc[i,y] = 1
    if user_sample_10000[x].quantile(.25) < user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.5):
        user_sample_10000.loc[i,y] = 2
    if user_sample_10000[x].quantile(.5) < user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.75):
        user_sample_10000.loc[i,y] = 3
    if user_sample_10000.loc[i,x] > user_sample_10000[x].quantile(.75):
        user_sample_10000.loc[i,y] = 4

# %%
user_sample_10000['total_compliments_tire'] = user_sample_10000['total_compliments_tire'].astype(int)

# %%
user_sample_10000['reactions_review_ratio'] = user_sample_10000['positive_reactions'] / user_sample_10000['review_count']
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59
# ...                      ...           ...                  ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54
#
#                                                   elite  fans  average_stars  \
# 0                                                  2007   267           3.91
# ...

# %%
user_sample_10000['reactions_review_ratio'].quantile([.25, .5, .75, 1])
# Out:
# 0.25      1.687500
# 0.50      2.755102
# 0.75      4.520336
# 1.00    105.082030
# Name: reactions_review_ratio, dtype: float64

# %%
x = 'reactions_review_ratio'
y = 'reactions_review_ratio_score'
for i in user_sample_10000.index:
    if user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.25):
        user_sample_10000.loc[i,y] = 1
    if user_sample_10000[x].quantile(.25) < user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.5):
        user_sample_10000.loc[i,y] = 2
    if user_sample_10000[x].quantile(.5) < user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.75):
        user_sample_10000.loc[i,y] = 3
    if user_sample_10000.loc[i,x] > user_sample_10000[x].quantile(.75):
        user_sample_10000.loc[i,y] = 4

# %%
user_sample_10000['reactions_review_ratio_score'].astype(int)
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       1
#        ..
# 9995    2
# 9996    2
# 9997    3
# 9998    1
# 9999    2
# Name: reactions_review_ratio_score, Length: 10000, dtype: int32

# %%
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59
# ...                      ...           ...                  ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54
#
#                                                   elite  fans  average_stars  \
# 0                                                  2007   267           3.91
# ...

# %%
x = 'total_compliments_tire'
y = 'reactions_review_ratio_score'
for i in user_sample_10000.index:
    user_sample_10000.loc[i, 'user_score'] = user_sample_10000.loc[i,x] + user_sample_10000.loc[i,y]

# %%
user_sample_10000['user_score'].quantile([0.25,.5,.75,1])
# Out:
# 0.25    3.0
# 0.50    5.0
# 0.75    7.0
# 1.00    8.0
# Name: user_score, dtype: float64

# %%
x = 'user_score'
y = 'user_tier'
for i in user_sample_10000.index:
    if user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.25):
        user_sample_10000.loc[i,y] = 'Bronze'
    if user_sample_10000[x].quantile(.25) < user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.5):
        user_sample_10000.loc[i,y] = 'Siviler'
    if user_sample_10000[x].quantile(.5) < user_sample_10000.loc[i,x] <= user_sample_10000[x].quantile(.75):
        user_sample_10000.loc[i,y] = 'Gold'
    if user_sample_10000.loc[i,x] > user_sample_10000[x].quantile(.75):
        user_sample_10000.loc[i,y] = 'Platinum'

# %%
user_sample_10000
# Out:
#                      user_id  review_count        yelping_since  \
# 0     qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26
# 1     j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 2     2WnXYQFK0hXEoTxPtV2zvg           665  2008-07-25 10:41:00
# 3     SZDeASXq7o05mMNLshsdIA           224  2005-11-29 04:38:33
# 4     hA5lMy-EnncsH4JoR-hFGQ            79  2007-01-05 19:40:59
# ...                      ...           ...                  ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w             5  2010-07-17 20:19:51
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ            43  2010-10-09 21:28:32
# 9997  nbF6fWySgbbD15TGSOKN6Q            43  2010-09-19 00:13:03
# 9998  rVuP6BdGt_8QF7PA0kRyvQ           392  2011-07-15 22:54:35
# 9999  fPvAAXp-B-fTS3_HOxvqlg            76  2008-07-06 04:11:54
#
#                                                   elite  fans  average_stars  \
# 0                                                  2007   267           3.91
# ...

# %%
user_tier_sample = user_sample_10000.copy()

# %%
user_tier_sample = user_tier_sample.drop(columns = [ 'review_count', 'total_compliments', 'positive_reactions', 'total_compliments_tire', 'user_score'])

# %%
user_tier_sample
# Out:
#                      user_id        yelping_since  \
# 0     qVc8ODYU5SZjKXVBgXdI7w  2007-01-25 16:47:26
# 1     j14WgRoU_-2ZE1aw1dXrJg  2009-01-25 04:35:42
# 2     2WnXYQFK0hXEoTxPtV2zvg  2008-07-25 10:41:00
# 3     SZDeASXq7o05mMNLshsdIA  2005-11-29 04:38:33
# 4     hA5lMy-EnncsH4JoR-hFGQ  2007-01-05 19:40:59
# ...                      ...                  ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w  2010-07-17 20:19:51
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ  2010-10-09 21:28:32
# 9997  nbF6fWySgbbD15TGSOKN6Q  2010-09-19 00:13:03
# 9998  rVuP6BdGt_8QF7PA0kRyvQ  2011-07-15 22:54:35
# 9999  fPvAAXp-B-fTS3_HOxvqlg  2008-07-06 04:11:54
#
#                                                   elite  fans  average_stars  \
# 0                                                  2007   267           3.91
# 1     2009,2010,2011,2012,2013,2014,2015,2016,2017,2...  3138           3.74
# 2                              2009,2010,2011,2012,2013    52           3.32
# ...

# %%
user_tier_sample = user_tier_sample.drop(columns = [ 'yelping_since', 'elite', 'reactions_review_ratio', 'reactions_review_ratio_score'])

# %%
user_tier_sample
# Out:
#                      user_id  fans  average_stars user_tier
# 0     qVc8ODYU5SZjKXVBgXdI7w   267           3.91  Platinum
# 1     j14WgRoU_-2ZE1aw1dXrJg  3138           3.74  Platinum
# 2     2WnXYQFK0hXEoTxPtV2zvg    52           3.32  Platinum
# 3     SZDeASXq7o05mMNLshsdIA    28           4.27      Gold
# 4     hA5lMy-EnncsH4JoR-hFGQ     1           3.54    Bronze
# ...                      ...   ...            ...       ...
# 9995  Ry6R2TMTQOInMXJR2TJh4w     0           3.20    Bronze
# 9996  UnHIN6t0MVRdC0Jo9oD9PQ     5           4.25   Siviler
# 9997  nbF6fWySgbbD15TGSOKN6Q     5           3.74   Siviler
# 9998  rVuP6BdGt_8QF7PA0kRyvQ     9           3.44    Bronze
# 9999  fPvAAXp-B-fTS3_HOxvqlg     6           3.86   Siviler
#
# [10000 rows x 4 columns]

# %% [markdown]
# # categorize review

# %%
review_sample_10000
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5     JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 6     6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  year  positive_reviews
# ...

# %%
review_sample_10000['positive_reviews'].quantile([.25, .5, .75, 1])
# Out:
# 0.25     0.0
# 0.50     0.0
# 0.75     1.0
# 1.00    59.0
# Name: positive_reviews, dtype: float64

# %%
review_sample_10000['positive_reviews'].describe()
# Out:
# count    6142.000000
# mean        1.061055
# std         2.620865
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        59.000000
# Name: positive_reviews, dtype: float64

# %%
# drop positive_reviews, year
review_sample = review_sample_10000.drop(columns = ['positive_reviews', 'year'])
review_sample
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5     JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
# 6     6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars
# 0         3
# 3         5
# ...

# %% [markdown]
# ## combine review_sample ,user_tier_sample and Business_open

# %%
sample_user_tier_10000 = user_tier_sample.merge(review_sample, on = 'user_id').merge(Business_open, on = 'business_id',suffixes=('_review', '_business'))

# %%
sample_user_tier_10000
# Out:
#                     user_id  fans  average_stars user_tier  \
# 0    Q5jOFJYhIsN8ouJ1rnsLQQ    36           3.79      Gold
# 1    oJMwdSEcl59FlX7cwaf0bA    76           4.16  Platinum
# 2    ci7Q6NvXQ8UZrBHusVX18g   227           3.27  Platinum
# 3    STO9KprPS0pZVO75VX_bvA     4           3.66   Siviler
# 4    S4YZloQTAbIkqTNsfAFfnA     2           3.64    Bronze
# ..                      ...   ...            ...       ...
# 126  ikWD8meznb14w9yNie3bwQ    65           3.99      Gold
# 127  ikWD8meznb14w9yNie3bwQ    65           3.99      Gold
# 128  1apGBB2xx4LAYxzYnXxsCQ     0           4.66    Bronze
# 129  noxaMHJFoBDFio1D3OF6Qg     0           2.71   Siviler
# 130  TI3dyNuTh7OnR26w26pXJg     3           3.65    Bronze
#
#                   review_id             business_id  stars_review  \
# 0    51xA8Ukh8TNnybnJ40kyAw  d8tLbQ9o3aVdOLgueJtYXw             4
# 1    l0Uj4urEWWlhg0qp8In9Yg  -ujBP1Dw0j1-Ffaz97-LXQ             5
# ...

# %%
sample_user_tier_10000.groupby(by  = 'business_id').count().sort_values(by = 'review_id', ascending = False).head(10)
# Out:
#                         user_id  fans  average_stars  user_tier  review_id  \
# business_id
# I0I2mkCOPTYVSLpc8A8VVw        2     2              2          2          2
# jMZ56S8Y1t7cA1Ob-d-qeA        2     2              2          2          2
# N5ekxQd7wGHWJJK-p9qqXw        2     2              2          2          2
# kZ3L75t_7EqE9kRS6bpWSA        2     2              2          2          2
# grjFEAN9gXOKQFEta4yBJg        2     2              2          2          2
# ZY2feSm2sc5nTXYHnKpMGQ        2     2              2          2          2
# 8uF-bhJFgT4Tn6DTb27viA        2     2              2          2          2
# hS6KNGCQVTYUdLb2edt58g        1     1              1          1          1
# h4C7s_Go9UKo5twaLIWc8A        1     1              1          1          1
# hiEj-3X8gV4-kBNkySOSJw        1     1              1          1          1
#
#                         stars_review  name  address  city  state  postal_code  \
# business_id
# ...

# %%
# add columns of user_weight
x = 'user_tier'
y = 'user_weight'
for i in sample_user_tier_10000.index:
    if sample_user_tier_10000.loc[i, x] == 'Bronze':
        sample_user_tier_10000.loc[i, y] = 0.2
    if sample_user_tier_10000.loc[i, x] == 'Siviler':
        sample_user_tier_10000.loc[i, y] = 0.23
    if sample_user_tier_10000.loc[i, x] == 'Gold':
        sample_user_tier_10000.loc[i, y] = 0.27
    if sample_user_tier_10000.loc[i, x] == 'Platinum':
        sample_user_tier_10000.loc[i, y] = 0.3

# %%
sample_user_tier_10000
# Out:
#                     user_id  fans  average_stars user_tier  \
# 0    Q5jOFJYhIsN8ouJ1rnsLQQ    36           3.79      Gold
# 1    oJMwdSEcl59FlX7cwaf0bA    76           4.16  Platinum
# 2    ci7Q6NvXQ8UZrBHusVX18g   227           3.27  Platinum
# 3    STO9KprPS0pZVO75VX_bvA     4           3.66   Siviler
# 4    S4YZloQTAbIkqTNsfAFfnA     2           3.64    Bronze
# ..                      ...   ...            ...       ...
# 126  ikWD8meznb14w9yNie3bwQ    65           3.99      Gold
# 127  ikWD8meznb14w9yNie3bwQ    65           3.99      Gold
# 128  1apGBB2xx4LAYxzYnXxsCQ     0           4.66    Bronze
# 129  noxaMHJFoBDFio1D3OF6Qg     0           2.71   Siviler
# 130  TI3dyNuTh7OnR26w26pXJg     3           3.65    Bronze
#
#                   review_id             business_id  stars_review  \
# 0    51xA8Ukh8TNnybnJ40kyAw  d8tLbQ9o3aVdOLgueJtYXw             4
# 1    l0Uj4urEWWlhg0qp8In9Yg  -ujBP1Dw0j1-Ffaz97-LXQ             5
# ...

# %%
def w_avg(df, stars_review, user_weight):
    d = df[stars_review]
    w = df[user_weight]
    
    return (d * w).sum() / w.sum()

# %%
star_after_weight = sample_user_tier_10000[['business_id','review_id', 'stars_review', 'user_weight']].groupby(by = ['business_id'], as_index=False).apply(lambda x: x)
star_after_weight
# Out:
#                 business_id               review_id  stars_review  user_weight
# 0    d8tLbQ9o3aVdOLgueJtYXw  51xA8Ukh8TNnybnJ40kyAw             4         0.27
# 1    -ujBP1Dw0j1-Ffaz97-LXQ  l0Uj4urEWWlhg0qp8In9Yg             5         0.30
# 2    V6Om7YZhlRQRU7WfuxHq8Q  g7MfpJGKQUGowCvIcrB91A             4         0.30
# 3    TF4IyHKK05m5rXENCK94nA  8k_TKP8Rh0y1twcWgQa2bg             2         0.23
# 4    ZY2feSm2sc5nTXYHnKpMGQ  UFchSpDYI1zvDBPZm1WqAg             4         0.20
# ..                      ...                     ...           ...          ...
# 126  sr-5EY6bmp4jINhea06MjA  OzIFDf9WJeWbWGV6N0j1pw             5         0.27
# 127  _cdy7hVc32mleVooP8x0Sw  N3KYe6JXDcGmpiUgelR1zQ             4         0.27
# 128  1QVB0_-piu0GXes87BXeGw  xmL_sY5yMYi9Uq8ZgjJb4w             5         0.20
# 129  ltBBYdNzkeKdCNPDAsxwAA  ymbDu_j2XrNFcYItj4GWfw             1         0.23
# 130  xhe3Z5cd-FYbR1DfFwx6OQ  2Ug2CyS6DINgI8G2bQICLA             5         0.20
#
# [131 rows x 4 columns]

# %%
star_after_weight = sample_user_tier_10000[['business_id','review_id', 'stars_review','user_weight']].groupby(by = ['business_id'], as_index=False).apply(w_avg, 'stars_review', 'user_weight')
star_after_weight
# Out:
#                 business_id  NaN
# 0    -OIUunijjcq_ZzyyQhPPFQ  5.0
# 1    -kAaeJxXCtLNAo3DosoXXA  4.0
# 2    -ujBP1Dw0j1-Ffaz97-LXQ  5.0
# 3    -zsvmEbkd-K9K2DAAKqiEQ  4.0
# 4    0a8t_Th0jtWUMmtq0q2dqA  5.0
# ..                      ...  ...
# 119  uW2oyOCEN3RgS7j2MfUIkg  5.0
# 120  v72HalBu5fQIFTD-oqhSgQ  2.0
# 121  vN6v8m4DO45Z4pp8yxxF_w  5.0
# 122  xhe3Z5cd-FYbR1DfFwx6OQ  5.0
# 123  yN6jZyG1G1FG_HCZQlJZ1g  5.0
#
# [124 rows x 2 columns]

# %%
star_after_weight.rename(columns=str).rename(columns={'nan':'new_lbldd'})
# Out:
#                 business_id  None
# 0    -OIUunijjcq_ZzyyQhPPFQ   5.0
# 1    -kAaeJxXCtLNAo3DosoXXA   4.0
# 2    -ujBP1Dw0j1-Ffaz97-LXQ   5.0
# 3    -zsvmEbkd-K9K2DAAKqiEQ   4.0
# 4    0a8t_Th0jtWUMmtq0q2dqA   5.0
# ..                      ...   ...
# 119  uW2oyOCEN3RgS7j2MfUIkg   5.0
# 120  v72HalBu5fQIFTD-oqhSgQ   2.0
# 121  vN6v8m4DO45Z4pp8yxxF_w   5.0
# 122  xhe3Z5cd-FYbR1DfFwx6OQ   5.0
# 123  yN6jZyG1G1FG_HCZQlJZ1g   5.0
#
# [124 rows x 2 columns]

# %%
star_after_weight = star_after_weight.rename(columns=str).rename(columns={'None':'review_star_after_weight'})
star_after_weight
# Out:
#                 business_id  review_star_after_weight
# 0    -OIUunijjcq_ZzyyQhPPFQ                       5.0
# 1    -kAaeJxXCtLNAo3DosoXXA                       4.0
# 2    -ujBP1Dw0j1-Ffaz97-LXQ                       5.0
# 3    -zsvmEbkd-K9K2DAAKqiEQ                       4.0
# 4    0a8t_Th0jtWUMmtq0q2dqA                       5.0
# ..                      ...                       ...
# 119  uW2oyOCEN3RgS7j2MfUIkg                       5.0
# 120  v72HalBu5fQIFTD-oqhSgQ                       2.0
# 121  vN6v8m4DO45Z4pp8yxxF_w                       5.0
# 122  xhe3Z5cd-FYbR1DfFwx6OQ                       5.0
# 123  yN6jZyG1G1FG_HCZQlJZ1g                       5.0
#
# [124 rows x 2 columns]

# %% [markdown]
# # 重新 join Business_open——> new dataframe with unique business_id

# %%
final_dataframe = Business_open[['business_id', 'name', 'stars']].merge(star_after_weight, how = 'right', on = 'business_id')
final_dataframe
# Out:
#                 business_id                         name  stars  \
# 0    -OIUunijjcq_ZzyyQhPPFQ              Zorba's Taverna    4.5
# 1    -kAaeJxXCtLNAo3DosoXXA               The Burg Diner    4.0
# 2    -ujBP1Dw0j1-Ffaz97-LXQ            Lama Dog Tap Room    4.0
# 3    -zsvmEbkd-K9K2DAAKqiEQ  Salty's Island Bar & Grille    4.0
# 4    0a8t_Th0jtWUMmtq0q2dqA                     DK Sushi    3.5
# ..                      ...                          ...    ...
# 119  uW2oyOCEN3RgS7j2MfUIkg  The Bearded Lady Barbershop    4.5
# 120  v72HalBu5fQIFTD-oqhSgQ               1200 Chophouse    4.5
# 121  vN6v8m4DO45Z4pp8yxxF_w    Surrey's Café & Juice Bar    4.5
# 122  xhe3Z5cd-FYbR1DfFwx6OQ    Riverside Day Spa & Nails    4.0
# 123  yN6jZyG1G1FG_HCZQlJZ1g                City Barbeque    4.0
#
#      review_star_after_weight
# 0                         5.0
# 1                         4.0
# 2                         5.0
# 3                         4.0
# 4                         5.0
# ...

# %%
final_dataframe.describe()
# Out:
#             stars  review_star_after_weight
# count  124.000000                124.000000
# mean     3.947581                  4.020475
# std      0.509338                  1.110149
# min      3.000000                  1.000000
# 25%      3.500000                  3.000000
# 50%      4.000000                  4.000000
# 75%      4.500000                  5.000000
# max      5.000000                  5.000000

# %%
final_dataframe.boxplot()
# Out:
# <AxesSubplot:>

# %%
final_dataframe['newnew_star']=final_dataframe.mean(axis = (1))
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_35300/2600267901.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   final_dataframe['newnew_star']=final_dataframe.mean(axis = (1))

# %%
final_dataframe
# Out:
#                 business_id                         name  stars  \
# 0    -OIUunijjcq_ZzyyQhPPFQ              Zorba's Taverna    4.5
# 1    -kAaeJxXCtLNAo3DosoXXA               The Burg Diner    4.0
# 2    -ujBP1Dw0j1-Ffaz97-LXQ            Lama Dog Tap Room    4.0
# 3    -zsvmEbkd-K9K2DAAKqiEQ  Salty's Island Bar & Grille    4.0
# 4    0a8t_Th0jtWUMmtq0q2dqA                     DK Sushi    3.5
# ..                      ...                          ...    ...
# 119  uW2oyOCEN3RgS7j2MfUIkg  The Bearded Lady Barbershop    4.5
# 120  v72HalBu5fQIFTD-oqhSgQ               1200 Chophouse    4.5
# 121  vN6v8m4DO45Z4pp8yxxF_w    Surrey's Café & Juice Bar    4.5
# 122  xhe3Z5cd-FYbR1DfFwx6OQ    Riverside Day Spa & Nails    4.0
# 123  yN6jZyG1G1FG_HCZQlJZ1g                City Barbeque    4.0
#
#      review_star_after_weight  newnew_star
# 0                         5.0         4.75
# 1                         4.0         4.00
# 2                         5.0         4.50
# ...

# %%
final_dataframe.describe()
# Out:
#             stars  review_star_after_weight  newnew_star
# count  124.000000                124.000000   124.000000
# mean     3.947581                  4.020475     3.984028
# std      0.509338                  1.110149     0.684177
# min      3.000000                  1.000000     2.000000
# 25%      3.500000                  3.000000     3.500000
# 50%      4.000000                  4.000000     4.000000
# 75%      4.500000                  5.000000     4.500000
# max      5.000000                  5.000000     5.000000

# %%
newnew_star_rank = final_dataframe.sort_values(by = 'newnew_star', ascending  = False)
newnew_star_rank
# Out:
#                 business_id                                      name  stars  \
# 82   deVwhY98J_r69DVedK2x8A                   Sonrisa Old City Dental    5.0
# 5    0yGH62WGQy_W3JoR6L5Kew                             Ice Cream 504    5.0
# 118  uG3-LDsfeAyf02uITS-3Xg                           Then Comes Baby    5.0
# 70   _D7QoWuQKMXk0mEE7r_Ftw                            Chateau La VIn    5.0
# 25   D9p7-HsY9llYP3BaCVg4DA                               Cafe Soleil    5.0
# ..                      ...                                       ...    ...
# 23   CkFSi4DGPNKaz1jePJBwaw  Planned Parenthood - Tampa Health Center    3.0
# 48   S2Ho8yLxhKAa26pBAm6rxA      Creole House Restaurant & Oyster Bar    4.0
# 62   XXZqNGRUyGVLx8oNm6BtBA                               Wild Garlic    3.0
# 12   2A35Yi7mHQu9uT61M7VQow                                Los Nietos    3.5
# 24   D73evJ9PZKxO3E5TaThe3w                            Superior Grill    3.0
#
#      review_star_after_weight  newnew_star
# ...

# %%
newnew_star_rank.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
newnew_star_rank.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
newnew_star_rank.head(7).plot.scatter(x = 'name', y = 'newnew_star')
# Out:
# <AxesSubplot:xlabel='name', ylabel='newnew_star'>

# %% [markdown]
# # get first 25% top-rated business

# %%
newnew_star_rank.quantile([.25,.5,.75,1])
# Out:
#       stars  review_star_after_weight  newnew_star
# 0.25    3.5                       3.0          3.5
# 0.50    4.0                       4.0          4.0
# 0.75    4.5                       5.0          4.5
# 1.00    5.0                       5.0          5.0

# %%
business_25 = newnew_star_rank.head(n = (0.25 * (newnew_star_rank['newnew_star'].count())).astype('int64') )
business_25
# Out:
#                 business_id  \
# 82   deVwhY98J_r69DVedK2x8A
# 5    0yGH62WGQy_W3JoR6L5Kew
# 118  uG3-LDsfeAyf02uITS-3Xg
# 70   _D7QoWuQKMXk0mEE7r_Ftw
# 25   D9p7-HsY9llYP3BaCVg4DA
# 16   5TzAmqzksrUBB2tdHDQAUA
# 46   Qv_AemDjEtgTZDJUc266Iw
# 47   ROeacJQwBeh05Rqg7F6TCg
# 31   I0I2mkCOPTYVSLpc8A8VVw
# 68   ZiQiMlvgk19GrEEkN9kyRA
# 26   DOl21AqtT74dUZ3kvXNNcA
# 73   b3uiHiidUYqsNoLIEqZTAg
# 74   bN7-A2GlVz2Job3frIPy9w
# 75   bjsBMTS4RD7Bs35ugv_fPA
# 18   8uF-bhJFgT4Tn6DTb27viA
# 17   6JFTijOMHB46yBoyVOjPCA
# 0    -OIUunijjcq_ZzyyQhPPFQ
# 109  qs9d6iGos9UO4BzhVmJ9UA
# 100  l_EQPW5NIIfi9s8rQfSufg
# 121  vN6v8m4DO45Z4pp8yxxF_w
# 119  uW2oyOCEN3RgS7j2MfUIkg
# 10   1QVB0_-piu0GXes87BXeGw
# 37   Jx2AoB_IQOUrZ3s6fdAUSA
# 97   kKPJLiHIr9Gd9sYs3GhxDQ
# 99   lRbHFOIFuusN2WOR_ypQ_A
# 77   c-IgS6Pk6vMyax7Rbr38eA
# 103  nFjk0xVI9fNiVN__5g-m8Q
# 92   iCKF72z3fqRTF1vxdBZINQ
# 113  sr-5EY6bmp4jINhea06MjA
# 54   TDKBPcViJQDMrdUm6a9XZA
# 52   SlZJATE_TGUU8X34UJNi4g
#
# ...

# %%
(0.25 * (newnew_star_rank['newnew_star'].count())).astype('int64')
# Out:
# 31

# %% [markdown]
# # rejoin the business category data

# %%
Business_open
# Out:
#                    business_id                      name  \
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 7       qkRM_2X51Yqxk3btlwAQIg            Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                 Marshalls
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address            city state postal_code  \
# 1       87 Grasso Plaza Shopping Center          Affton    MO       63123
# 3                           935 Race St    Philadelphia    PA       19107
# ...

# %%
business_25 = business_25.merge(Business[['business_id', 'state', 'categories', 'attributes']], how = 'left', on = 'business_id')
business_25
# Out:
#                business_id                                               name  \
# 0   deVwhY98J_r69DVedK2x8A                            Sonrisa Old City Dental
# 1   0yGH62WGQy_W3JoR6L5Kew                                      Ice Cream 504
# 2   uG3-LDsfeAyf02uITS-3Xg                                    Then Comes Baby
# 3   _D7QoWuQKMXk0mEE7r_Ftw                                     Chateau La VIn
# 4   D9p7-HsY9llYP3BaCVg4DA                                        Cafe Soleil
# 5   5TzAmqzksrUBB2tdHDQAUA                             Hyde Perk Coffee House
# 6   Qv_AemDjEtgTZDJUc266Iw                                Albert Whitted Park
# 7   ROeacJQwBeh05Rqg7F6TCg                                                BAP
# 8   I0I2mkCOPTYVSLpc8A8VVw                                      Compère Lapin
# 9   ZiQiMlvgk19GrEEkN9kyRA                   The Blind Tiger Cafe - Ybor City
# 10  DOl21AqtT74dUZ3kvXNNcA                                    Golden Triangle
# ...

# %%
# how many business in usa  top 25%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
usa=business_25.loc[business_25['state'].isin(states)]
usa
# Out:
#                business_id                                               name  \
# 0   deVwhY98J_r69DVedK2x8A                            Sonrisa Old City Dental
# 1   0yGH62WGQy_W3JoR6L5Kew                                      Ice Cream 504
# 2   uG3-LDsfeAyf02uITS-3Xg                                    Then Comes Baby
# 3   _D7QoWuQKMXk0mEE7r_Ftw                                     Chateau La VIn
# 4   D9p7-HsY9llYP3BaCVg4DA                                        Cafe Soleil
# 5   5TzAmqzksrUBB2tdHDQAUA                             Hyde Perk Coffee House
# 6   Qv_AemDjEtgTZDJUc266Iw                                Albert Whitted Park
# 7   ROeacJQwBeh05Rqg7F6TCg                                                BAP
# 8   I0I2mkCOPTYVSLpc8A8VVw                                      Compère Lapin
# 9   ZiQiMlvgk19GrEEkN9kyRA                   The Blind Tiger Cafe - Ybor City
# 10  DOl21AqtT74dUZ3kvXNNcA                                    Golden Triangle
# ...

# %%
# how many business in canada  top 25%
states = ["ON", "QC", "NS", "NB", "MB", "BC", "PE", "SK", "AB", "NL"]
canada=business_25.loc[business_25['state'].isin(states)]
canada
# Out:
# Empty DataFrame
# Columns: [business_id, name, stars, review_star_after_weight, newnew_star, state, categories, attributes]
# Index: []

# %%
# test in 124 business

# %%
test_124 = newnew_star_rank.merge(Business[['business_id', 'state', 'categories', 'attributes']], how = 'left', on = 'business_id')

# %%
# how many business in canada  124
states = ["ON", "QC", "NS", "NB", "MB", "BC", "PE", "SK", "AB", "NL"]
canada_test_124=test_124.loc[test_124['state'].isin(states)]
canada_test_124
# Out:
#                business_id             name  stars  review_star_after_weight  \
# 76  JI3-QZwm6vihIFBcekgyaA     Matrix Hotel    4.0                       4.0
# 82  d8tLbQ9o3aVdOLgueJtYXw  Jay Bee's Diner    3.5                       4.0
#
#     newnew_star state                                         categories  \
# 76         4.00    AB  International, Hotels & Travel, Hotels, Restau...
# 82         3.75    AB  Diners, Restaurants, Breakfast & Brunch, Ameri...
#
#                                            attributes
# 76  {'WiFi': 'u'free'', 'RestaurantsPriceRange2': ...
# 82  {'NoiseLevel': 'u'average'', 'Ambience': '{'to...

# %%
# how many business in usa  124
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
usa_test_124=test_124.loc[test_124['state'].isin(states)]
usa_test_124
# Out:
#                 business_id                                      name  stars  \
# 0    deVwhY98J_r69DVedK2x8A                   Sonrisa Old City Dental    5.0
# 1    0yGH62WGQy_W3JoR6L5Kew                             Ice Cream 504    5.0
# 2    uG3-LDsfeAyf02uITS-3Xg                           Then Comes Baby    5.0
# 3    _D7QoWuQKMXk0mEE7r_Ftw                            Chateau La VIn    5.0
# 4    D9p7-HsY9llYP3BaCVg4DA                               Cafe Soleil    5.0
# ..                      ...                                       ...    ...
# 119  CkFSi4DGPNKaz1jePJBwaw  Planned Parenthood - Tampa Health Center    3.0
# 120  S2Ho8yLxhKAa26pBAm6rxA      Creole House Restaurant & Oyster Bar    4.0
# 121  XXZqNGRUyGVLx8oNm6BtBA                               Wild Garlic    3.0
# 122  2A35Yi7mHQu9uT61M7VQow                                Los Nietos    3.5
# 123  D73evJ9PZKxO3E5TaThe3w                            Superior Grill    3.0
#
# ...

# %%
usa_test_124[['business_id', 'state']].sort_values(by = 'state', ascending = False).groupby(by = 'state').apply(lambda x : x)
# Out:
#                 business_id state
# 27   iCKF72z3fqRTF1vxdBZINQ    TN
# 36   N5ekxQd7wGHWJJK-p9qqXw    TN
# 122  2A35Yi7mHQu9uT61M7VQow    TN
# 118  ltBBYdNzkeKdCNPDAsxwAA    TN
# 117  bmz4siaejdjs4_yS_mYW4A    TN
# ..                      ...   ...
# 13   bjsBMTS4RD7Bs35ugv_fPA    CA
# 42   -ujBP1Dw0j1-Ffaz97-LXQ    CA
# 12   bN7-A2GlVz2Job3frIPy9w    AZ
# 105  SLreQZjicOqB_7MCfJ8MdQ    AZ
# 101  fgTOJRkc703E4XRdcr5zRA    AZ
#
# [122 rows x 2 columns]

# %%
business_count_124 = usa_test_124.groupby(by = 'state', as_index= False).count().sort_values(by = 'business_id', ascending = False)
business_count_124
# Out:
#    state  business_id  name  stars  review_star_after_weight  newnew_star  \
# 10    PA           28    28     28                        28           28
# 6     LA           27    27     27                        27           27
# 2     FL           18    18     18                        18           18
# 5     IN           12    12     12                        12           12
# 11    TN           10    10     10                        10           10
# 9     NV            7     7      7                         7            7
# 1     CA            6     6      6                         6            6
# 7     MO            5     5      5                         5            5
# 0     AZ            3     3      3                         3            3
# 3     ID            3     3      3                         3            3
# 8     NJ            2     2      2                         2            2
# 4     IL            1     1      1                         1            1
#
# ...

# %%
business_count_124.plot.scatter(x = 'state', y = 'business_id')
# Out:
# <AxesSubplot:xlabel='state', ylabel='business_id'>

# %%
business_count_124.plot.bar(x = 'state', y = 'business_id')
# Out:
# <AxesSubplot:xlabel='state'>

# %%
# usa restaurant in 124 business

# %%
## select all restaurants in USA
us_restaurants=usa_test_124[usa_test_124['categories'].str.contains('Restaurants')]

## select out 16 cuisine types of restaurants and rename the category
us_restaurants.is_copy=False
us_restaurants['category']=pd.Series()
us_restaurants.loc[us_restaurants.categories.str.contains('Food'),'category'] = 'Food'
us_restaurants.loc[us_restaurants.categories.str.contains('American'),'category'] = 'American'
us_restaurants.loc[us_restaurants.categories.str.contains('Mexican'), 'category'] = 'Mexican'
us_restaurants.loc[us_restaurants.categories.str.contains('Italian'), 'category'] = 'Italian'
us_restaurants.loc[us_restaurants.categories.str.contains('Japanese'), 'category'] = 'Japanese'
us_restaurants.loc[us_restaurants.categories.str.contains('Chinese'), 'category'] = 'Chinese'
us_restaurants.loc[us_restaurants.categories.str.contains('Thai'), 'category'] = 'Thai'
us_restaurants.loc[us_restaurants.categories.str.contains('Mediterranean'), 'category'] = 'Mediterranean'
us_restaurants.loc[us_restaurants.categories.str.contains('French'), 'category'] = 'French'
us_restaurants.loc[us_restaurants.categories.str.contains('Vietnamese'), 'category'] = 'Vietnamese'
us_restaurants.loc[us_restaurants.categories.str.contains('Greek'),'category'] = 'Greek'
us_restaurants.loc[us_restaurants.categories.str.contains('Indian'),'category'] = 'Indian'
us_restaurants.loc[us_restaurants.categories.str.contains('Korean'),'category'] = 'Korean'
us_restaurants.loc[us_restaurants.categories.str.contains('Hawaiian'),'category'] = 'Hawaiian'
us_restaurants.loc[us_restaurants.categories.str.contains('African'),'category'] = 'African'
us_restaurants.loc[us_restaurants.categories.str.contains('Spanish'),'category'] = 'Spanish'
us_restaurants.loc[us_restaurants.categories.str.contains('Middle_eastern'),'category'] = 'Middle_eastern'
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_35300/133018880.py:6: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   us_restaurants['category']=pd.Series()
# C:\Users\Admin\AppData\Local\Temp/ipykernel_35300/133018880.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_restaurants['category']=pd.Series()
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
us_restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 4 to 123
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   business_id               78 non-null     object
#  1   name                      78 non-null     object
#  2   stars                     78 non-null     float64
#  3   review_star_after_weight  78 non-null     float64
#  4   newnew_star               78 non-null     float64
#  5   state                     78 non-null     object
#  6   categories                78 non-null     object
#  7   attributes                78 non-null     object
#  8   category                  65 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 6.1+ KB

# %%
## check total number of us restaurants
us_restaurants.shape
# Out:
# (78, 9)

# %%
us_restaurants
# Out:
#                 business_id                                  name  stars  \
# 4    D9p7-HsY9llYP3BaCVg4DA                           Cafe Soleil    5.0
# 7    ROeacJQwBeh05Rqg7F6TCg                                   BAP    4.5
# 8    I0I2mkCOPTYVSLpc8A8VVw                         Compère Lapin    4.5
# 9    ZiQiMlvgk19GrEEkN9kyRA      The Blind Tiger Cafe - Ybor City    4.5
# 10   DOl21AqtT74dUZ3kvXNNcA                       Golden Triangle    4.5
# ..                      ...                                   ...    ...
# 118  ltBBYdNzkeKdCNPDAsxwAA                                Tavern    4.0
# 120  S2Ho8yLxhKAa26pBAm6rxA  Creole House Restaurant & Oyster Bar    4.0
# 121  XXZqNGRUyGVLx8oNm6BtBA                           Wild Garlic    3.0
# 122  2A35Yi7mHQu9uT61M7VQow                            Los Nietos    3.5
# 123  D73evJ9PZKxO3E5TaThe3w                        Superior Grill    3.0
#
#      review_star_after_weight  newnew_star state  \
# ...

# %%
# > 0.5 -> weak relationship
us_restaurants['newnew_star'].corr(us_restaurants['stars'])
# Out:
# 0.538878007631156

# %%
us_restaurants['newnew_star'].corr(us_restaurants['review_star_after_weight'])
# Out:
# 0.9494084376902445

# %% [markdown]
# ## newnew_star review_count corr

# %%
us_restaurants_review_count = us_restaurants.merge(Business_open[['business_id' ,'review_count']], how = 'left', on = 'business_id')
us_restaurants_review_count
# Out:
#                business_id                                  name  stars  \
# 0   D9p7-HsY9llYP3BaCVg4DA                           Cafe Soleil    5.0
# 1   ROeacJQwBeh05Rqg7F6TCg                                   BAP    4.5
# 2   I0I2mkCOPTYVSLpc8A8VVw                         Compère Lapin    4.5
# 3   ZiQiMlvgk19GrEEkN9kyRA      The Blind Tiger Cafe - Ybor City    4.5
# 4   DOl21AqtT74dUZ3kvXNNcA                       Golden Triangle    4.5
# ..                     ...                                   ...    ...
# 73  ltBBYdNzkeKdCNPDAsxwAA                                Tavern    4.0
# 74  S2Ho8yLxhKAa26pBAm6rxA  Creole House Restaurant & Oyster Bar    4.0
# 75  XXZqNGRUyGVLx8oNm6BtBA                           Wild Garlic    3.0
# 76  2A35Yi7mHQu9uT61M7VQow                            Los Nietos    3.5
# 77  D73evJ9PZKxO3E5TaThe3w                        Superior Grill    3.0
#
#     review_star_after_weight  newnew_star state  \
# 0                        5.0         5.00    FL
# ...

# %%
# <0.25 -> No relationship
us_restaurants_review_count['newnew_star'].corr(us_restaurants_review_count['review_count'])
# Out:
# 0.03543735106206685

# %%
# <0.25 -> No relationship
us_restaurants_review_count['stars'].corr(us_restaurants_review_count['review_count'])
# Out:
# 0.2182885743520553

# %%
# <0.25 -> No relationship
us_restaurants_review_count['review_star_after_weight'].corr(us_restaurants_review_count['review_count'])
# Out:
# -0.04061509677516635

# %%
us_restaurants_review_count.corr()
# Out:
#                              stars  review_star_after_weight  newnew_star  \
# stars                     1.000000                  0.247070     0.538878
# review_star_after_weight  0.247070                  1.000000     0.949408
# newnew_star               0.538878                  0.949408     1.000000
# review_count              0.218289                 -0.040615     0.035437
#
#                           review_count
# stars                         0.218289
# review_star_after_weight     -0.040615
# newnew_star                   0.035437
# review_count                  1.000000

# %% [markdown]
# ## 和user_tier的corr

# %%
us_restaurants
# Out:
#                 business_id                                  name  stars  \
# 4    D9p7-HsY9llYP3BaCVg4DA                           Cafe Soleil    5.0
# 7    ROeacJQwBeh05Rqg7F6TCg                                   BAP    4.5
# 8    I0I2mkCOPTYVSLpc8A8VVw                         Compère Lapin    4.5
# 9    ZiQiMlvgk19GrEEkN9kyRA      The Blind Tiger Cafe - Ybor City    4.5
# 10   DOl21AqtT74dUZ3kvXNNcA                       Golden Triangle    4.5
# ..                      ...                                   ...    ...
# 118  ltBBYdNzkeKdCNPDAsxwAA                                Tavern    4.0
# 120  S2Ho8yLxhKAa26pBAm6rxA  Creole House Restaurant & Oyster Bar    4.0
# 121  XXZqNGRUyGVLx8oNm6BtBA                           Wild Garlic    3.0
# 122  2A35Yi7mHQu9uT61M7VQow                            Los Nietos    3.5
# 123  D73evJ9PZKxO3E5TaThe3w                        Superior Grill    3.0
#
#      review_star_after_weight  newnew_star state  \
# ...

# %%
# add user_tier column
star_after_weight = sample_user_tier_10000[['business_id','review_id', 'stars_review','user_tier', 'user_weight']].groupby(by = ['business_id'], as_index=False).apply(lambda x: x)
star_after_weight
# Out:
#                 business_id               review_id  stars_review user_tier  \
# 0    d8tLbQ9o3aVdOLgueJtYXw  51xA8Ukh8TNnybnJ40kyAw             4      Gold
# 1    -ujBP1Dw0j1-Ffaz97-LXQ  l0Uj4urEWWlhg0qp8In9Yg             5  Platinum
# 2    V6Om7YZhlRQRU7WfuxHq8Q  g7MfpJGKQUGowCvIcrB91A             4  Platinum
# 3    TF4IyHKK05m5rXENCK94nA  8k_TKP8Rh0y1twcWgQa2bg             2   Siviler
# 4    ZY2feSm2sc5nTXYHnKpMGQ  UFchSpDYI1zvDBPZm1WqAg             4    Bronze
# ..                      ...                     ...           ...       ...
# 126  sr-5EY6bmp4jINhea06MjA  OzIFDf9WJeWbWGV6N0j1pw             5      Gold
# 127  _cdy7hVc32mleVooP8x0Sw  N3KYe6JXDcGmpiUgelR1zQ             4      Gold
# 128  1QVB0_-piu0GXes87BXeGw  xmL_sY5yMYi9Uq8ZgjJb4w             5    Bronze
# 129  ltBBYdNzkeKdCNPDAsxwAA  ymbDu_j2XrNFcYItj4GWfw             1   Siviler
# 130  xhe3Z5cd-FYbR1DfFwx6OQ  2Ug2CyS6DINgI8G2bQICLA             5    Bronze
#
#      user_weight
# 0           0.27
# 1           0.30
# ...

# %%
us_restaurants_user_tier_corr = star_after_weight[['user_tier', 'business_id','user_weight']].merge(us_restaurants, how = 'right')
us_restaurants_user_tier_corr
# Out:
#    user_tier             business_id  user_weight  \
# 0       Gold  D9p7-HsY9llYP3BaCVg4DA         0.27
# 1     Bronze  ROeacJQwBeh05Rqg7F6TCg         0.20
# 2   Platinum  I0I2mkCOPTYVSLpc8A8VVw         0.30
# 3    Siviler  I0I2mkCOPTYVSLpc8A8VVw         0.23
# 4   Platinum  ZiQiMlvgk19GrEEkN9kyRA         0.30
# ..       ...                     ...          ...
# 79   Siviler  ltBBYdNzkeKdCNPDAsxwAA         0.23
# 80   Siviler  S2Ho8yLxhKAa26pBAm6rxA         0.23
# 81  Platinum  XXZqNGRUyGVLx8oNm6BtBA         0.30
# 82    Bronze  2A35Yi7mHQu9uT61M7VQow         0.20
# 83  Platinum  D73evJ9PZKxO3E5TaThe3w         0.30
#
#                                     name  stars  review_star_after_weight  \
# 0                            Cafe Soleil    5.0                       5.0
# 1                                    BAP    4.5                       5.0
# 2                          Compère Lapin    4.5                       5.0
# ...

# %%
# <0.25 -> No relationship
us_restaurants_user_tier_corr['newnew_star'].corr(us_restaurants_user_tier_corr['user_weight'])
# Out:
# -0.08066456047454662

# %%
# <0.25 -> No relationship
us_restaurants_user_tier_corr['review_star_after_weight'].corr(us_restaurants_user_tier_corr['user_weight'])
# Out:
# -0.15302898556689845

# %%
us_restaurants_user_tier_corr.corr()
# Out:
#                           user_weight     stars  review_star_after_weight  \
# user_weight                  1.000000  0.159782                 -0.153029
# stars                        0.159782  1.000000                  0.273340
# review_star_after_weight    -0.153029  0.273340                  1.000000
# newnew_star                 -0.080665  0.557570                  0.950923
#
#                           newnew_star
# user_weight                 -0.080665
# stars                        0.557570
# review_star_after_weight     0.950923
# newnew_star                  1.000000

# %%
# usa restaurant in first 25% of 124 business

# %%
## select all restaurants in USA
us_restaurants=usa[usa['categories'].str.contains('Restaurants')]

## select out 16 cuisine types of restaurants and rename the category
us_restaurants.is_copy=False
us_restaurants['category']=pd.Series()
us_restaurants.loc[us_restaurants.categories.str.contains('American'),'category'] = 'American'
us_restaurants.loc[us_restaurants.categories.str.contains('Mexican'), 'category'] = 'Mexican'
us_restaurants.loc[us_restaurants.categories.str.contains('Italian'), 'category'] = 'Italian'
us_restaurants.loc[us_restaurants.categories.str.contains('Japanese'), 'category'] = 'Japanese'
us_restaurants.loc[us_restaurants.categories.str.contains('Chinese'), 'category'] = 'Chinese'
us_restaurants.loc[us_restaurants.categories.str.contains('Thai'), 'category'] = 'Thai'
us_restaurants.loc[us_restaurants.categories.str.contains('Mediterranean'), 'category'] = 'Mediterranean'
us_restaurants.loc[us_restaurants.categories.str.contains('French'), 'category'] = 'French'
us_restaurants.loc[us_restaurants.categories.str.contains('Vietnamese'), 'category'] = 'Vietnamese'
us_restaurants.loc[us_restaurants.categories.str.contains('Greek'),'category'] = 'Greek'
us_restaurants.loc[us_restaurants.categories.str.contains('Indian'),'category'] = 'Indian'
us_restaurants.loc[us_restaurants.categories.str.contains('Korean'),'category'] = 'Korean'
us_restaurants.loc[us_restaurants.categories.str.contains('Hawaiian'),'category'] = 'Hawaiian'
us_restaurants.loc[us_restaurants.categories.str.contains('African'),'category'] = 'African'
us_restaurants.loc[us_restaurants.categories.str.contains('Spanish'),'category'] = 'Spanish'
us_restaurants.loc[us_restaurants.categories.str.contains('Middle_eastern'),'category'] = 'Middle_eastern'
us_restaurants.category
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_31040/2922750973.py:6: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   us_restaurants['category']=pd.Series()
# C:\Users\Admin\AppData\Local\Temp/ipykernel_31040/2922750973.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_restaurants['category']=pd.Series()
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
us_restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 4 to 123
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   business_id               78 non-null     object
#  1   name                      78 non-null     object
#  2   stars                     78 non-null     float64
#  3   review_star_after_weight  78 non-null     float64
#  4   newnew_star               78 non-null     float64
#  5   state                     78 non-null     object
#  6   categories                78 non-null     object
#  7   attributes                78 non-null     object
#  8   category                  65 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 6.1+ KB

# %%
#

# %%
# groupby

# %%
test_124['modified_categories'] = np.where(test_124['categories'].str.contains('Active Life'), 'Active Life',
                                         np.where(test_124['categories'].str.contains('Arts & Entertainment'), 'Arts & Entertainment',
                                         np.where(test_124['categories'].str.contains('Automotive'), 'Automotive',
                                         np.where(test_124['categories'].str.contains('Beauty & Spas'), 'Beauty & Spas',
                                         np.where(test_124['categories'].str.contains('Education'), 'Education', 
                                         np.where(test_124['categories'].str.contains('Event Planning & Services'), 'Event Planning & Services',
                                         np.where(test_124['categories'].str.contains('Financial Services'), 'Financial Services', 
                                         np.where(test_124['categories'].str.contains('Food'), 'Food',        
                                         np.where(test_124['categories'].str.contains('Health & Medical'), 'Health & Medical',
                                         np.where(test_124['categories'].str.contains('Home Services'), 'Home Services',
                                         np.where(test_124['categories'].str.contains('Hotels & Travel'), 'Hotels & Travel',
                                         np.where(test_124['categories'].str.contains('Local Flavor'), 'Local Flavor',
                                         np.where(test_124['categories'].str.contains('Local Services'), 'Local Services',         
                                         np.where(test_124['categories'].str.contains('Mass Media'), 'Mass Media',
                                         np.where(test_124['categories'].str.contains('Nightlife'), 'Nightlife',
                                         np.where(test_124['categories'].str.contains('Pets'), 'Pets',
                                         np.where(test_124['categories'].str.contains('Professional Services'), 'Professional Services',
                                         np.where(test_124['categories'].str.contains('Public Services & Government'), 'Public Services & Government',         
                                         np.where(test_124['categories'].str.contains('Real Estate'), 'Real Estate',
                                         np.where(test_124['categories'].str.contains('Religious Organizations'), 'Religious Organizations',         
                                         np.where(test_124['categories'].str.contains('Restaurants'), 'Restaurants', 
                                         np.where(test_124['categories'].str.contains('Shopping'), 'Shopping', 'else'))))))))))))))))))))))
test_124
# Out:
#                 business_id                                      name  stars  \
# 0    deVwhY98J_r69DVedK2x8A                   Sonrisa Old City Dental    5.0
# 1    0yGH62WGQy_W3JoR6L5Kew                             Ice Cream 504    5.0
# 2    uG3-LDsfeAyf02uITS-3Xg                           Then Comes Baby    5.0
# 3    _D7QoWuQKMXk0mEE7r_Ftw                            Chateau La VIn    5.0
# 4    D9p7-HsY9llYP3BaCVg4DA                               Cafe Soleil    5.0
# ..                      ...                                       ...    ...
# 119  CkFSi4DGPNKaz1jePJBwaw  Planned Parenthood - Tampa Health Center    3.0
# 120  S2Ho8yLxhKAa26pBAm6rxA      Creole House Restaurant & Oyster Bar    4.0
# 121  XXZqNGRUyGVLx8oNm6BtBA                               Wild Garlic    3.0
# 122  2A35Yi7mHQu9uT61M7VQow                                Los Nietos    3.5
# 123  D73evJ9PZKxO3E5TaThe3w                            Superior Grill    3.0
#
# ...

# %%
test_124_groupby = test_124.groupby(by = 'modified_categories', as_index = False).count().sort_values(by = 'business_id', ascending = False)
test_124_groupby
# Out:
#           modified_categories  business_id  name  stars  \
# 4                        Food           37    37     37
# 9                 Restaurants           28    28     28
# 3   Event Planning & Services           17    17     17
# 8                   Nightlife           11    11     11
# 1        Arts & Entertainment           10    10     10
# 0                 Active Life            5     5      5
# 2               Beauty & Spas            4     4      4
# 5            Health & Medical            4     4      4
# 10                   Shopping            4     4      4
# 6               Home Services            3     3      3
# 7             Hotels & Travel            1     1      1
#
#     review_star_after_weight  newnew_star  state  categories  attributes
# 4                         37           37     37          37          37
# 9                         28           28     28          28          28
# ...

# %%
test_124_groupby['business_id'].plot.bar()
# Out:
# <AxesSubplot:>
